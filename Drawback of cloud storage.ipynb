# %%
df = spark.read.csv(
    path="/Volumes/databricks_training_ey_4006035021251163/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    inferSchema=True,
    header=True
)
display(df)

# %%
df.write.save(
    format="parquet",
    path="/Volumes/databricks_training_ey_4006035021251163/quickstart_schema/sandbox/dataset/output_parquet",
    mode="overwrite",
)

# %%
df_parquet = spark.read.parquet("/Volumes/databricks_training_ey_4006035021251163/quickstart_schema/sandbox/dataset/output_parquet")
display(df_parquet)

# %%
df_parquet.createOrReplaceTempView("user_vw")

# %%
# %sql
UPDATE
  user_vw
SET
  country = 'Bharath'
where
  country = 'India'

# %%
from pyspark.sql.functions import col
df.filter(col("country")=="India").write.save(
    format="parquet",
    path="/Volumes/databricks_training_ey_4006035021251163/quickstart_schema/sandbox/dataset/output_parquet",
    mode="overwrite",
)
