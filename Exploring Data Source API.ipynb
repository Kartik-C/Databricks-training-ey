# %% [markdown]
# #Create Dataframes
#
# In Spark the dataframe reader is the class which reads data from different sources.

# %%
dfr = spark.read
print(type(dfr))

# %%
df = spark.read.csv(
    "/Volumes/databricks_training_ey/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
print(df)
df.printSchema()
df.count()
print(df.rdd.getNumPartitions())

# %%
spark.read.json(
    path="/Volumes/databricks_training_ey/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",
    multiLine=True,
).display()

# %%
df = spark.read.csv(
    path="/Volumes/databricks_training_ey/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",
    sep="|",
    header=True,
    inferSchema=True
)
df.printSchema()
df.display()
